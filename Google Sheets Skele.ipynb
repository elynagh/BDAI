# %%
# Import pandas and api functions from gspread
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
# Set up api calling credentials for Google Sheets
scope = ['https://spreadsheets.google.com/feeds']
credentials = ServiceAccountCredentials.from_json_keyfile_name('./MyProject-7e31e82736b9.json', scope)
gc = gspread.authorize(credentials)

# %%
# Calls the spreadsheet and creats a table of data from data within the called sheet
spreadsheet_key = '1VaNR-L0-HNy0w3_3WX3OXbuE7QDuqxlYfx7ZJN3jQ0c'
book = gc.open_by_key(spreadsheet_key)
worksheet = book.worksheet("Technology")
table = worksheet.get_all_values()

# %%
table
# Out:
# [['Market Analysis',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'General Information',
#   ''],
#  ['Ticker',
#   'Actual Price',
#   '% Change',
#   'Volatility Ranking\n(1 - 5)*',
#   'Analyst Valuation Estimate',
#   'Rank',
#   'Market Cap\n(In Billions)',
#   'PE Ratio',
#   'EPS',
#   '52-Week Spread\n(52wk high - 52wk low)',
#   'Beta',
#   '',
#   'Industry Researcher',
#   'Alex Dimmick'],
#  ['FB',
#   '$145.37',
#   '-3.7',
#   '1',
#   '',
#   '',
#   '419.72',
#   '22.47',
#   '6.47',
#   '$74.82',
#   '0.42',
#   '',
#   'Estimation Date',
#   '9/23/2018'],
#  ['AAPL',
#   '$216.30',
#   '-1.59',
#   '3',
#   '',
#   '',
#   '1044.71',
#   '19.62',
#   '11.02',
#   '$83.23',
#   '1.41',
#   '',
#   'Summary and Notes',
#   ''],
#  ['AMZN',
#   '$1,642.81',
#   '-7.82',
#   '4',
#   '',
#   '',
#   '801.27',
#   '92.1',
#   '17.84',
#   '$1,081.95',
#   '1.58',
#   '',
#   '',
#   ''],
#  ['ORCL',
#   '$47.32',
# ...

# %%
##Convert table data into a dataframe
df = pd.DataFrame(table[1:], columns=table[0])

##Only keep columns we need
df = df[['Market Analysis']]

##Convert number strings to floats and ints
df = df.apply(pd.to_numeric, errors='ignore')


df.head()
# Out:
#   Market Analysis
# 0          Ticker
# 1              FB
# 2            AAPL
# 3            AMZN
# 4            ORCL
